# %%
import pandas as pd

# %%
Table1= pd.read_csv(r"C:\Users\16479\Downloads\customers.csv")

# %%
Table1
# Out:
#       id           cust_name  num_products province  len_relationship
# 0   1001      Johnny Awesome             3       ON                 1  \
# 1   1002          Bob Marley             4       ON                 1
# 2   1004        Taylor Swift             2       AB                 2
# 3   1101          James Dean             3       BC                 3
# 4   1006       Stephen Smith             5       ON                 4
# 5   1014       Delilah Avery             2       AB                 3
# 6   1254        Johnson Cory             1       AB                 4
# 7   1285          Maria Alva             5       ON                 2
# 8   1354        Jessica Fast             4       BC                 5
# 9   1005  Mariah Anita Smith             2       BC                 3
# 10  1008      Robert Optimus             3       MB                10
# 11  1585        Steven Prime             5       AB                 2
# ...

# %%
Table1=Table1.rename(columns={'id':'customer_id'})

# %%
Table1.set_index('customer_id', inplace=True)

# %%
Table1.head(10)
# Out:
#                       cust_name  num_products province  len_relationship
# customer_id
# 1001             Johnny Awesome             3       ON                 1  \
# 1002                 Bob Marley             4       ON                 1
# 1004               Taylor Swift             2       AB                 2
# 1101                 James Dean             3       BC                 3
# 1006              Stephen Smith             5       ON                 4
# 1014              Delilah Avery             2       AB                 3
# 1254               Johnson Cory             1       AB                 4
# 1285                 Maria Alva             5       ON                 2
# 1354               Jessica Fast             4       BC                 5
# 1005         Mariah Anita Smith             2       BC                 3
#
#                 cust_category
# customer_id
# 1001                   wealth
# 1002         personal_banking
# 1004                      hnw
# ...

# %%
Table1.tail()
# Out:
#                       cust_name  num_products province  len_relationship
# customer_id
# 1354               Jessica Fast             4       BC                 5  \
# 1005         Mariah Anita Smith             2       BC                 3
# 1008             Robert Optimus             3       MB                10
# 1585               Steven Prime             5       AB                 2
# 1475          Stephanie Element             2       ON                 5
#
#                 cust_category
# customer_id
# 1354         personal_banking
# 1005         personal_banking
# 1008                      hnw
# 1585                   wealth
# 1475         personal_banking

# %%
Table1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13 entries, 1001 to 1475
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cust_name         13 non-null     object
#  1   num_products      13 non-null     int64
#  2   province          13 non-null     object
#  3   len_relationship  13 non-null     int64
#  4   cust_category     13 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 624.0+ bytes

# %%
Table1.index
# Out:
# Index([1001, 1002, 1004, 1101, 1006, 1014, 1254, 1285, 1354, 1005, 1008, 1585,
#        1475],
#       dtype='int64', name='customer_id')

# %%
Table1.columns
# Out:
# Index(['cust_name', 'num_products', 'province', 'len_relationship',
#        'cust_category'],
#       dtype='object')

# %%
Table1.axes
# Out:
# [Index([1001, 1002, 1004, 1101, 1006, 1014, 1254, 1285, 1354, 1005, 1008, 1585,
#         1475],
#        dtype='int64', name='customer_id'),
#  Index(['cust_name', 'num_products', 'province', 'len_relationship',
#         'cust_category'],
#        dtype='object')]

# %%
Table1.dtypes
# Out:
# cust_name           object
# num_products         int64
# province            object
# len_relationship     int64
# cust_category       object
# dtype: object

# %%
Table1.columns=('Customers','Num_products','Province','Relationship','Category')
Table1
# Out:
#                       Customers  Num_products Province  Relationship
# customer_id
# 1001             Johnny Awesome             3       ON             1  \
# 1002                 Bob Marley             4       ON             1
# 1004               Taylor Swift             2       AB             2
# 1101                 James Dean             3       BC             3
# 1006              Stephen Smith             5       ON             4
# 1014              Delilah Avery             2       AB             3
# 1254               Johnson Cory             1       AB             4
# 1285                 Maria Alva             5       ON             2
# 1354               Jessica Fast             4       BC             5
# 1005         Mariah Anita Smith             2       BC             3
# 1008             Robert Optimus             3       MB            10
# 1585               Steven Prime             5       AB             2
# ...

# %%
Table1.rename(columns={'Num_products':'Products'})
# Out:
#                       Customers  Products Province  Relationship
# customer_id
# 1001             Johnny Awesome         3       ON             1  \
# 1002                 Bob Marley         4       ON             1
# 1004               Taylor Swift         2       AB             2
# 1101                 James Dean         3       BC             3
# 1006              Stephen Smith         5       ON             4
# 1014              Delilah Avery         2       AB             3
# 1254               Johnson Cory         1       AB             4
# 1285                 Maria Alva         5       ON             2
# 1354               Jessica Fast         4       BC             5
# 1005         Mariah Anita Smith         2       BC             3
# 1008             Robert Optimus         3       MB            10
# 1585               Steven Prime         5       AB             2
# 1475          Stephanie Element         2       ON             5
#
#                      Category
# ...

# %%
Table1.sort_index(axis=0,ascending=True)
# Out:
#                       Customers  Num_products Province  Relationship
# customer_id
# 1001             Johnny Awesome             3       ON             1  \
# 1002                 Bob Marley             4       ON             1
# 1004               Taylor Swift             2       AB             2
# 1005         Mariah Anita Smith             2       BC             3
# 1006              Stephen Smith             5       ON             4
# 1008             Robert Optimus             3       MB            10
# 1014              Delilah Avery             2       AB             3
# 1101                 James Dean             3       BC             3
# 1254               Johnson Cory             1       AB             4
# 1285                 Maria Alva             5       ON             2
# 1354               Jessica Fast             4       BC             5
# 1475          Stephanie Element             2       ON             5
# ...

# %%
Table1.sort_index(axis=1,ascending=True)
# Out:
#                      Category           Customers  Num_products Province
# customer_id
# 1001                   wealth      Johnny Awesome             3       ON  \
# 1002         personal_banking          Bob Marley             4       ON
# 1004                      hnw        Taylor Swift             2       AB
# 1101                   wealth          James Dean             3       BC
# 1006                      hnw       Stephen Smith             5       ON
# 1014         personal_banking       Delilah Avery             2       AB
# 1254                      hnw        Johnson Cory             1       AB
# 1285                   wealth          Maria Alva             5       ON
# 1354         personal_banking        Jessica Fast             4       BC
# 1005         personal_banking  Mariah Anita Smith             2       BC
# 1008                      hnw      Robert Optimus             3       MB
# 1585                   wealth        Steven Prime             5       AB
# ...

# %%
Table1.Category
# Out:
# customer_id
# 1001              wealth
# 1002    personal_banking
# 1004                 hnw
# 1101              wealth
# 1006                 hnw
# 1014    personal_banking
# 1254                 hnw
# 1285              wealth
# 1354    personal_banking
# 1005    personal_banking
# 1008                 hnw
# 1585              wealth
# 1475    personal_banking
# Name: Category, dtype: object

# %%
Table1['Category']
# Out:
# customer_id
# 1001              wealth
# 1002    personal_banking
# 1004                 hnw
# 1101              wealth
# 1006                 hnw
# 1014    personal_banking
# 1254                 hnw
# 1285              wealth
# 1354    personal_banking
# 1005    personal_banking
# 1008                 hnw
# 1585              wealth
# 1475    personal_banking
# Name: Category, dtype: object

# %%
Table1[['Category','Customers']]
# Out:
#                      Category           Customers
# customer_id
# 1001                   wealth      Johnny Awesome
# 1002         personal_banking          Bob Marley
# 1004                      hnw        Taylor Swift
# 1101                   wealth          James Dean
# 1006                      hnw       Stephen Smith
# 1014         personal_banking       Delilah Avery
# 1254                      hnw        Johnson Cory
# 1285                   wealth          Maria Alva
# 1354         personal_banking        Jessica Fast
# 1005         personal_banking  Mariah Anita Smith
# 1008                      hnw      Robert Optimus
# 1585                   wealth        Steven Prime
# 1475         personal_banking   Stephanie Element

# %%
Table1.loc[1002]
# Out:
# Customers             Bob Marley
# Num_products                   4
# Province                      ON
# Relationship                   1
# Category        personal_banking
# Name: 1002, dtype: object

# %%
Table1.loc[[1002,1001]]
# Out:
#                   Customers  Num_products Province  Relationship
# customer_id
# 1002             Bob Marley             4       ON             1  \
# 1001         Johnny Awesome             3       ON             1
#
#                      Category
# customer_id
# 1002         personal_banking
# 1001                   wealth

# %%
Table1.iloc[3]
# Out:
# Customers       James Dean
# Num_products             3
# Province                BC
# Relationship             3
# Category            wealth
# Name: 1101, dtype: object

# %%
Table1.iloc[4:6]
# Out:
#                  Customers  Num_products Province  Relationship
# customer_id
# 1006         Stephen Smith             5       ON             4  \
# 1014         Delilah Avery             2       AB             3
#
#                      Category
# customer_id
# 1006                      hnw
# 1014         personal_banking

# %%
Table1.loc[1101:,:'Province']
# Out:
#                       Customers  Num_products Province
# customer_id
# 1101                 James Dean             3       BC
# 1006              Stephen Smith             5       ON
# 1014              Delilah Avery             2       AB
# 1254               Johnson Cory             1       AB
# 1285                 Maria Alva             5       ON
# 1354               Jessica Fast             4       BC
# 1005         Mariah Anita Smith             2       BC
# 1008             Robert Optimus             3       MB
# 1585               Steven Prime             5       AB
# 1475          Stephanie Element             2       ON

# %%
Table1[Table1['Province']=="BC"]
# Out:
#                       Customers  Num_products Province  Relationship
# customer_id
# 1101                 James Dean             3       BC             3  \
# 1354               Jessica Fast             4       BC             5
# 1005         Mariah Anita Smith             2       BC             3
#
#                      Category
# customer_id
# 1101                   wealth
# 1354         personal_banking
# 1005         personal_banking

# %%
Table1[(Table1['Province']=="BC")&(Table1['Category']=="wealth")]
# Out:
#               Customers  Products Province  Relationship Category
# customer_id
# 1101         James Dean         3       BC             3   wealth

# %%
Table1[Table1.index.isin([1002])]
# Out:
#               Customers  Num_products Province  Relationship          Category
# customer_id
# 1002         Bob Marley             4       ON             1  personal_banking

# %%
Table1=Table1.rename(columns={'Num_products':'Products'})
Table1[Table1['Products'].isin(range(2,4))]
# Out:
#                       Customers  Products Province  Relationship
# customer_id
# 1001             Johnny Awesome         3       ON             1  \
# 1004               Taylor Swift         2       AB             2
# 1101                 James Dean         3       BC             3
# 1014              Delilah Avery         2       AB             3
# 1005         Mariah Anita Smith         2       BC             3
# 1008             Robert Optimus         3       MB            10
# 1475          Stephanie Element         2       ON             5
#
#                      Category
# customer_id
# 1001                   wealth
# 1004                      hnw
# 1101                   wealth
# 1014         personal_banking
# 1005         personal_banking
# 1008                      hnw
# 1475         personal_banking

# %%
Table1[Table1['Province'].isin(['ON','AB'])]
# Out:
#                      Customers  Products Province  Relationship
# customer_id
# 1001            Johnny Awesome         3       ON             1  \
# 1002                Bob Marley         4       ON             1
# 1004              Taylor Swift         2       AB             2
# 1006             Stephen Smith         5       ON             4
# 1014             Delilah Avery         2       AB             3
# 1254              Johnson Cory         1       AB             4
# 1285                Maria Alva         5       ON             2
# 1585              Steven Prime         5       AB             2
# 1475         Stephanie Element         2       ON             5
#
#                      Category
# customer_id
# 1001                   wealth
# 1002         personal_banking
# 1004                      hnw
# 1006                      hnw
# 1014         personal_banking
# 1254                      hnw
# 1285                   wealth
# 1585                   wealth
# ...

# %%
Table1[Table1['Province'].isin(['ON','AB']) & Table1['Products'].isin(range(2,4))]
# Out:
#                      Customers  Products Province  Relationship
# customer_id
# 1001            Johnny Awesome         3       ON             1  \
# 1004              Taylor Swift         2       AB             2
# 1014             Delilah Avery         2       AB             3
# 1475         Stephanie Element         2       ON             5
#
#                      Category
# customer_id
# 1001                   wealth
# 1004                      hnw
# 1014         personal_banking
# 1475         personal_banking

# %%
Table1[Table1.Customers.str.lower().str.contains('m')]
# Out:
#                       Customers  Products Province  Relationship
# customer_id
# 1001             Johnny Awesome         3       ON             1  \
# 1002                 Bob Marley         4       ON             1
# 1101                 James Dean         3       BC             3
# 1006              Stephen Smith         5       ON             4
# 1285                 Maria Alva         5       ON             2
# 1005         Mariah Anita Smith         2       BC             3
# 1008             Robert Optimus         3       MB            10
# 1585               Steven Prime         5       AB             2
# 1475          Stephanie Element         2       ON             5
#
#                      Category
# customer_id
# 1001                   wealth
# 1002         personal_banking
# 1101                   wealth
# 1006                      hnw
# 1285                   wealth
# 1005         personal_banking
# 1008                      hnw
# 1585                   wealth
# ...

# %%
Table1.loc[Table1.Customers.str.lower().str.contains('m'),['Province']]
# Out:
#             Province
# customer_id
# 1001              ON
# 1002              ON
# 1101              BC
# 1006              ON
# 1285              ON
# 1005              BC
# 1008              MB
# 1585              AB
# 1475              ON

# %%
Table2=Table1.set_index('Customers').drop('James Dean')

# %%
Table2
# Out:
#                     Products Province  Relationship          Category
# Customers
# Johnny Awesome             3       ON             1            wealth
# Bob Marley                 4       ON             1  personal_banking
# Taylor Swift               2       AB             2               hnw
# Stephen Smith              5       ON             4               hnw
# Delilah Avery              2       AB             3  personal_banking
# Johnson Cory               1       AB             4               hnw
# Maria Alva                 5       ON             2            wealth
# Jessica Fast               4       BC             5  personal_banking
# Mariah Anita Smith         2       BC             3  personal_banking
# Robert Optimus             3       MB            10               hnw
# Steven Prime               5       AB             2            wealth
# Stephanie Element          2       ON             5  personal_banking

# %%
Table1.sort_values('Relationship',ascending=True)
# Out:
#                       Customers  Products Province  Relationship
# customer_id
# 1001             Johnny Awesome         3       ON             1  \
# 1002                 Bob Marley         4       ON             1
# 1004               Taylor Swift         2       AB             2
# 1285                 Maria Alva         5       ON             2
# 1585               Steven Prime         5       AB             2
# 1101                 James Dean         3       BC             3
# 1014              Delilah Avery         2       AB             3
# 1005         Mariah Anita Smith         2       BC             3
# 1006              Stephen Smith         5       ON             4
# 1254               Johnson Cory         1       AB             4
# 1354               Jessica Fast         4       BC             5
# 1475          Stephanie Element         2       ON             5
# 1008             Robert Optimus         3       MB            10
#
#                      Category
# ...

# %%
Table1group= Table1.groupby('Province')

# %%
Table1group.groups
# Out:
# {'AB': [1004, 1014, 1254, 1585], 'BC': [1101, 1354, 1005], 'MB': [1008], 'ON': [1001, 1002, 1006, 1285, 1475]}

# %%
Table1group.get_group('ON')
# Out:
#                      Customers  Products Province  Relationship
# customer_id
# 1001            Johnny Awesome         3       ON             1  \
# 1002                Bob Marley         4       ON             1
# 1006             Stephen Smith         5       ON             4
# 1285                Maria Alva         5       ON             2
# 1475         Stephanie Element         2       ON             5
#
#                      Category
# customer_id
# 1001                   wealth
# 1002         personal_banking
# 1006                      hnw
# 1285                   wealth
# 1475         personal_banking

# %%
print(type(Table1group))
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>

# %%
Table1group.mean('Product')
# Out:
#           Products  Relationship
# Province
# AB             2.5      2.750000
# BC             3.0      3.666667
# MB             3.0     10.000000
# ON             3.8      2.600000

# %%
Table1group.median('Product')
# Out:
#           Products  Relationship
# Province
# AB             2.0           2.5
# BC             3.0           3.0
# MB             3.0          10.0
# ON             4.0           2.0

# %%
Table1.groupby('Province')[['Products','Relationship']].aggregate(['mean','max','min'])
# Out:
#          Products         Relationship
#              mean max min         mean max min
# Province
# AB            2.5   5   1     2.750000   4   2
# BC            3.0   4   2     3.666667   5   3
# MB            3.0   3   3    10.000000  10  10
# ON            3.8   5   2     2.600000   5   1

# %%
Table1.describe()
# Out:
#         Products  Relationship
# count  13.000000     13.000000
# mean    3.153846      3.461538
# std     1.344504      2.366974
# min     1.000000      1.000000
# 25%     2.000000      2.000000
# 50%     3.000000      3.000000
# 75%     4.000000      4.000000
# max     5.000000     10.000000

# %%
TableT = pd.read_csv(r"C:\Users\16479\Downloads\transactions.csv")
TableT.set_index('customer_id',inplace=True)
TableT
# Out:
#              id txn_type  txn_total
# customer_id
# 1001          1    Debit     165.78
# 1001          2   Credit      42.10
# 1001          4   Credit     103.03
# 1001          5   Credit      56.60
# 1002          6    Debit     214.34
# 1002          7     Cash     115.69
# 1002          8    Debit      21.37
# 1004          9     Cash     227.58
# 1004         10   Credit       5.92
# 1006         11    Debit     225.89
# 1014         12     Cash      67.96
# 1254         13    Debit     235.79
# 1285         14     Cash     160.89
# 1354         15   Credit     377.26
# 1005         16    Debit     276.01
# 1008         17   Credit     190.02
# 1585         18    Debit     320.40
# 1475         19     Cash     328.72
# 1014         20    Debit     449.39
# 1254         21     Cash      15.26
# 1285         22   Credit     393.91
# 1354         23    Debit      94.32
# 1005         24    Debit     403.62
# 1008         25     Cash     242.73
# ...

# %%
FinalTable = pd.merge(left=Table1, right=TableT, on='customer_id')

# %%
FinalTable
# Out:
#                       Customers  Products Province  Relationship
# customer_id
# 1001             Johnny Awesome         3       ON             1  \
# 1001             Johnny Awesome         3       ON             1
# 1001             Johnny Awesome         3       ON             1
# 1001             Johnny Awesome         3       ON             1
# 1002                 Bob Marley         4       ON             1
# 1002                 Bob Marley         4       ON             1
# 1002                 Bob Marley         4       ON             1
# 1004               Taylor Swift         2       AB             2
# 1004               Taylor Swift         2       AB             2
# 1006              Stephen Smith         5       ON             4
# 1014              Delilah Avery         2       AB             3
# 1014              Delilah Avery         2       AB             3
# 1014              Delilah Avery         2       AB             3
# ...

# %%
FinalTable.median()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\nanops.py:786, in nanmedian(values, axis, skipna, mask)
#     785 try:
# --> 786     values = values.astype("f8")
#     787 except ValueError as err:
#     788     # e.g. "could not convert string to float: 'a'"
#
# ValueError: could not convert string to float: 'Johnny Awesome'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 FinalTable.median()
#
# ...

# %%
FinalTable.groupby('Customers')['txn_total'].aggregate(['mean','max','min'])
# Out:
#                           mean     max     min
# Customers
# Bob Marley          117.133333  214.34   21.37
# Delilah Avery       233.476667  449.39   67.96
# Jessica Fast        303.290000  438.29   94.32
# Johnny Awesome       91.877500  165.78   42.10
# Johnson Cory        168.753333  255.21   15.26
# Maria Alva          270.466667  393.91  160.89
# Mariah Anita Smith  267.230000  403.62  122.06
# Robert Optimus      199.730000  242.73  166.44
# Stephanie Element   227.466667  328.72   87.38
# Stephen Smith       225.890000  225.89  225.89
# Steven Prime        286.183333  320.40  230.24
# Taylor Swift        116.750000  227.58    5.92

# %%
FinalTable.isnull().count()
# Out:
# Customers       34
# Products        34
# Province        34
# Relationship    34
# Category        34
# id              34
# txn_type        34
# txn_total       34
# dtype: int64

# %%
FinalTable.isna().count()
# Out:
# Customers       34
# Products        34
# Province        34
# Relationship    34
# Category        34
# id              34
# txn_type        34
# txn_total       34
# dtype: int64
